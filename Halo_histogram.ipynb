# %%
import matplotlib.pyplot as plt
import numpy as np

halo_number = np.array([121167, 11006, 10051, 8821, 8143, 7553, 6668, 5918, 5659, 5500, 5374, 5252,
                       5015, 4709, 4442, 3970, 3928, 3265, 3070, 3060])
mass = np.array([1600, 2600, 3600, 4600, 5600, 6600 , 7600, 8600, 9600, 10600, 11600, 12600, 13600, 14600,
                15600, 16600, 17600, 18600, 19600, 20600])

plt.bar(mass, halo_number , width=900 , color='green',label='Halo hisstogram predicted by RF')
plt.xlabel('Halo Mass')
plt.ylabel('number of halos')
plt.legend()
plt.show()
